# %% [markdown]
# <a href="https://colab.research.google.com/github/RaoSunny124/AI_201/blob/main/My_image_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
api_key = userdata.get("My_chatbot")

# %%
# !pip install -q -U google.generativeai    #-q for quiet

# %%
import google.generativeai as gnai

# %%
gnai.configure(api_key= api_key)

# %%
model_name = "gemini-1.5-flash"

# %%
model = gnai.GenerativeModel(model_name)

# %%
# import PIL.Image as img
# image = img.open("JPN file.jpeg")
# display(image)


# response = model.generate_content(["Explain image in detail?" , image])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
import requests
from io import BytesIO
from PIL import Image
from IPython.display import display
url = "https://pixlr.com/images/generator/how-to-generate.webp"
response = requests.get(url)
image = Image.open(BytesIO(response.content))
display(image)
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1024x1024>

# %%
prompt = "Explain image in detail?"

# %%
response = model.generate_content([image , prompt])

# %%
print(response.text)
# Out:
# Close-up view of a stylized, futuristic camera.
#
#
# Here's a breakdown of the image:
#
# * **Design:** The camera is not realistic; it's a concept design with exaggerated features. The body is a mix of dark metallics and textured fabric-like sections. Orange highlights accentuate the curves and edges. The lens is particularly prominent, large, and glows with an inner yellow-orange light, giving it a powerful, almost sci-fi feel.  Various buttons, dials, and markings are visible, but they are stylized and not clearly labeled in a way a real camera would be.
#
# ...
